# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshanaHeendeniya/ML_Learning/blob/main/Day1_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authenticate in the Note book

import os
from google.colab import userdata
import google.generativeai as genai

try:
  GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
  os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # For libraries that rely on env var
  genai.configure(api_key=GOOGLE_API_KEY)
  print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %%
# Import the specific components from the Agent Development Kit and the Generative AI library.

from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Configure retry options

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.

research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.

summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.

root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
# Create the ochestrating environment (runner) and run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The latest advancements in quantum computing are set to significantly impact AI. Quantum computers, with their ability to process information exponentially faster using qubits, can help AI overcome current limitations. This enhanced computational power will enable AI to solve complex problems that are currently intractable for classical computers, leading to breakthroughs in areas like drug discovery, materials science, and logistics optimization.
#
# Furthermore, quantum computing promises to improve AI performance by making data processing more efficient, resulting in more accurate models. It also offers a more sustainable and energy-efficient path for training large AI models, addressing concerns about the high computational cost of current AI.
#
# Specific AI fields like Natural Language Processing, drug discovery, healthcare, optimization, and autonomous vehicles are expected to be revolutionized. However, the field is still in its early stages, facing challenges in hardware stability and error correction. Hybrid quantum-classical approaches are likely to be key to realizing the full potential of Quantum AI in the near future.

# %% [markdown]
# ## Sequential Workflows - The Assembly Line

# %% [markdown]
# Blog Post Creation with Sequential Agents
#
#
#
# 1.   Outline Agent - Creates a blog outline for a given topic
# 2.   Writer Agent - Writes a blog post
#
#
# 1.   Editor Agent - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.

outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.

writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.

editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
# Create root agent. Root agent is a sequential agent which runs it sub agents in the order they are listed.

root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
# Run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline:
#
# **Headline:** Supercharge Your Software: Unlocking the Power of Multi-Agent Systems
#
# **Introduction Hook:** Tired of monolithic codebases that are hard to manage and scale? Imagine a world where your software components work together like a well-oiled machine, each with its own intelligence and purpose. That world is here, and it's called Multi-Agent Systems (MAS).
#
# ---
#
# ### Main Section 1: Enhanced Modularity and Specialization
#
# *   **Decoupled Complexity:** Break down large, intricate problems into smaller, manageable agents, each responsible for a specific task or domain. This makes your codebase significantly easier to understand, develop, and debug.
# *   **Focused Expertise:** Each agent can be designed and optimized for its particular function, leading to more efficient and specialized solutions. Think of them as microservices with brains.
# *   **Independent Development & Deployment:** Agents can be developed, tested, and deployed independently, allowing for faster iteration cycles and reduced dependencies between development teams.
#
# ---
#
# ### Main Section 2: Improved Robustness and Resilience
#
# *   **Fault Tolerance:** If one agent fails, the system can often continue to operate, albeit potentially with reduced functionality. Other agents can potentially take over or compensate for the failing agent.
# *   **Graceful Degradation:** Instead of a complete system crash, MAS can often "gracefully degrade" in performance or features when a component experiences issues, providing a better user experience.
# *   **Dynamic Reconfiguration:** Agents can be added, removed, or modified at runtime, allowing systems to adapt to changing environments or requirements without significant downtime.
#
# ---
#
# ### Main Section 3: Advanced Problem Solving and Adaptability
#
# *   **Distributed Intelligence:** Complex problems can be tackled by multiple agents collaborating and sharing information, enabling solutions that are beyond the capabilities of a single, monolithic program.
# *   **Emergent Behavior:** Through interaction and communication, MAS can exhibit complex and often unexpected intelligent behaviors that were not explicitly programmed, leading to innovative solutions.
# *   **Adaptability to Dynamic Environments:** MAS excel in environments where conditions change rapidly. Agents can react to new information and adjust their behavior and strategies accordingly.
#
# ---
#
# ### Main Section 4 (Optional): Real-World Applications and Future Potential
#
# *   **Examples in Action:** Briefly touch upon applications like autonomous driving, supply chain optimization, smart grids, or sophisticated game AI where MAS are already making an impact.
# *   **The Future is Multi-Agent:** Discuss the growing importance of MAS as AI and distributed computing become more prevalent, and the potential for even more sophisticated and autonomous software.
#
# ---
#
# **Concluding Thought:** Multi-agent systems offer a paradigm shift in how we design and build software. By embracing modularity, resilience, and collaborative intelligence, developers can create systems that are not only more robust and scalable but also more intelligent and adaptable to the ever-evolving digital landscape. It's time to think beyond single programs and unlock the true potential of collective intelligence.
# WriterAgent > ## Supercharge Your Software: Unlocking the Power of Multi-Agent Systems
#
# Tired of monolithic codebases that are hard to manage and scale? Imagine a world where your software components work together like a well-oiled machine, each with its own intelligence and purpose. That world is here, and it's called Multi-Agent Systems (MAS).
#
# For developers, MAS offers a significant leap forward. Instead of wrestling with a single, unwieldy program, you can break down complex challenges into smaller, more manageable **agents**. Each agent can be a master of its own domain, leading to **enhanced modularity and specialization**. This makes development, debugging, and scaling far more straightforward, akin to having intelligent microservices.
#
# The benefits extend to **improved robustness**. If one agent encounters an issue, the system doesn't necessarily crash. Instead, it can often **gracefully degrade** or even continue operating as other agents compensate, providing a more resilient user experience. Plus, agents can be developed and deployed **independently**, speeding up your development cycles significantly.
#
# Beyond just better code management, MAS unlocks **advanced problem-solving and adaptability**. By allowing multiple agents to collaborate and share information, you can tackle problems previously out of reach for a single program. This distributed intelligence can even lead to **emergent behaviors** – ingenious solutions that arise organically from agent interactions. As AI and distributed computing advance, MAS is poised to redefine software development, powering everything from autonomous systems to intelligent networks. It’s time to embrace collective intelligence and build software that’s truly supercharged.
# EditorAgent > ## Supercharge Your Software: Unlocking the Power of Multi-Agent Systems
#
# Tired of wrestling with monolithic codebases that are difficult to manage and scale? Imagine a software architecture where your components work together seamlessly, like a well-oiled machine, each possessing its own intelligence and dedicated purpose. This vision is now a reality, powered by Multi-Agent Systems (MAS).
#
# For software developers, MAS represents a significant paradigm shift. Instead of grappling with a single, unwieldy program, you can decompose complex challenges into smaller, more manageable **agents**. Each agent can become a specialist in its own domain, leading to **enhanced modularity and specialization**. This approach dramatically simplifies development, debugging, and scaling, offering an intelligent evolution of the microservices concept.
#
# The advantages extend to **improved robustness and resilience**. If one agent encounters an issue, the entire system doesn't necessarily fail. Instead, it can often **gracefully degrade** its functionality or continue operating while other agents compensate, ensuring a more resilient user experience. Furthermore, the ability to develop and deploy agents **independently** significantly accelerates development cycles and reduces interdependencies.
#
# Beyond streamlining code management, MAS unlocks **advanced problem-solving capabilities and adaptability**. By enabling multiple agents to collaborate and share information, you can tackle problems previously insurmountable for a single program. This distributed intelligence can even foster **emergent behaviors** – ingenious solutions that arise organically from the interactions between agents. As advancements in AI and distributed computing continue, MAS is poised to redefine software development, powering everything from autonomous systems to intricate intelligent networks. It's time to embrace collective intelligence and build software that's truly supercharged.

# %%
# Part of agent.py --> Follow https://google.github.io/adk-docs/get-started/quickstart/ to learn the setup

# --- 1. Define Sub-Agents for Each Pipeline Stage ---

# Code Writer Agent
# Takes the initial specification (from user query) and writes code.
code_writer_agent = Agent(
    name="CodeWriterAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction
    instruction="""You are a Python Code Generator.
Based *only* on the user's request, write Python code that fulfills the requirement.
Output *only* the complete Python code block, enclosed in triple backticks (```python ... ```).
Do not add any other text before or after the code block.
""",
    description="Writes initial Python code based on a specification.",
    output_key="generated_code" # Stores output in state['generated_code']
)

# Code Reviewer Agent
# Takes the code generated by the previous agent (read from state) and provides feedback.
code_reviewer_agent = Agent(
    name="CodeReviewerAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction, correctly using state key injection
    instruction="""You are an expert Python Code Reviewer.
    Your task is to provide constructive feedback on the provided code.

    **Code to Review:**
    ```python
    {generated_code}
    ```

**Review Criteria:**
1.  **Correctness:** Does the code work as intended? Are there logic errors?
2.  **Readability:** Is the code clear and easy to understand? Follows PEP 8 style guidelines?
3.  **Efficiency:** Is the code reasonably efficient? Any obvious performance bottlenecks?
4.  **Edge Cases:** Does the code handle potential edge cases or invalid inputs gracefully?
5.  **Best Practices:** Does the code follow common Python best practices?

**Output:**
Provide your feedback as a concise, bulleted list. Focus on the most important points for improvement.
If the code is excellent and requires no changes, simply state: "No major issues found."
Output *only* the review comments or the "No major issues" statement.
""",
    description="Reviews code and provides feedback.",
    output_key="review_comments", # Stores output in state['review_comments']
)


# Code Refactorer Agent
# Takes the original code and the review comments (read from state) and refactors the code.
code_refactorer_agent = Agent(
    name="CodeRefactorerAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction, correctly using state key injection
    instruction="""You are a Python Code Refactoring AI.
Your goal is to improve the given Python code based on the provided review comments.

  **Original Code:**
  ```python
  {generated_code}
  ```

  **Review Comments:**
  {review_comments}

**Task:**
Carefully apply the suggestions from the review comments to refactor the original code.
If the review comments state "No major issues found," return the original code unchanged.
Ensure the final code is complete, functional, and includes necessary imports and docstrings.

**Output:**
Output *only* the final, refactored Python code block, enclosed in triple backticks (```python ... ```).
Do not add any other text before or after the code block.
""",
    description="Refactors code based on review comments.",
    output_key="refactored_code", # Stores output in state['refactored_code']
)


# --- 2. Create the SequentialAgent ---
# This agent orchestrates the pipeline by running the sub_agents in order.
code_pipeline_agent = SequentialAgent(
    name="CodePipelineAgent",
    sub_agents=[code_writer_agent, code_reviewer_agent, code_refactorer_agent],
    description="Executes a sequence of code writing, reviewing, and refactoring.",
    # The agents will run in the order provided: Writer -> Reviewer -> Refactorer
)

# For ADK tools compatibility, the root agent must be named `root_agent`
root_agent = code_pipeline_agent

# Run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a python code to create a fitness app"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a python code to create a fitness app
# CodeWriterAgent > ```python
# import datetime
#
# class User:
#     def __init__(self, name, age, gender, weight, height):
#         self.name = name
#         self.age = age
#         self.gender = gender
#         self.weight = weight  # in kg
#         self.height = height  # in meters
#         self.activity_log = []
#         self.goals = {}
#
#     def calculate_bmi(self):
#         if self.height <= 0:
#             return "Height must be positive."
#         return self.weight / (self.height ** 2)
#
#     def get_bmi_category(self):
#         bmi = self.calculate_bmi()
#         if isinstance(bmi, str):
#             return bmi
#         if bmi < 18.5:
#             return "Underweight"
#         elif 18.5 <= bmi < 24.9:
#             return "Normal weight"
#         elif 25 <= bmi < 29.9:
#             return "Overweight"
#         else:
#             return "Obesity"
#
#     def log_activity(self, activity_type, duration, calories_burned, date=None):
#         if date is None:
#             date = datetime.date.today()
#         self.activity_log.append({
#             "date": date,
#             "activity_type": activity_type,
#             "duration": duration,  # in minutes
#             "calories_burned": calories_burned
#         })
#         print(f"Activity logged: {activity_type} for {duration} minutes.")
#
#     def view_activity_log(self):
#         if not self.activity_log:
#             print("No activities logged yet.")
#             return
#         print(f"\n--- Activity Log for {self.name} ---")
#         for entry in self.activity_log:
#             print(f"Date: {entry['date']}, Activity: {entry['activity_type']}, Duration: {entry['duration']} mins, Calories: {entry['calories_burned']} kcal")
#         print("----------------------------")
#
#     def set_goal(self, goal_type, target_value):
#         self.goals[goal_type] = target_value
#         print(f"Goal set: {goal_type} - {target_value}")
#
#     def view_goals(self):
#         if not self.goals:
#             print("No goals set yet.")
#             return
#         print(f"\n--- Goals for {self.name} ---")
#         for goal_type, target_value in self.goals.items():
#             print(f"{goal_type}: {target_value}")
#         print("--------------------")
#
#     def __str__(self):
#         return (f"User Profile:\n"
#                 f"  Name: {self.name}\n"
#                 f"  Age: {self.age}\n"
#                 f"  Gender: {self.gender}\n"
#                 f"  Weight: {self.weight} kg\n"
#                 f"  Height: {self.height} m\n"
#                 f"  BMI: {self.calculate_bmi():.2f} ({self.get_bmi_category()})")
#
# class FitnessApp:
#     def __init__(self):
#         self.users = {}
#
#     def create_user(self, name, age, gender, weight, height):
#         if name in self.users:
#             print(f"User '{name}' already exists.")
#             return None
#         user = User(name, age, gender, weight, height)
#         self.users[name] = user
#         print(f"User '{name}' created successfully.")
#         return user
#
#     def get_user(self, name):
#         return self.users.get(name)
#
#     def display_dashboard(self, user_name):
#         user = self.get_user(user_name)
#         if not user:
#             print("User not found.")
#             return
#
#         print(f"\n=== Dashboard for {user.name} ===")
#         print(user)
#         user.view_goals()
#         user.view_activity_log()
#         print("============================")
#
#     def run(self):
#         while True:
#             print("\n--- Fitness App Menu ---")
#             print("1. Create User")
#             print("2. Login/Select User")
#             print("3. Exit")
#             choice = input("Enter your choice: ")
#
#             if choice == '1':
#                 name = input("Enter name: ")
#                 age = int(input("Enter age: "))
#                 gender = input("Enter gender: ")
#                 weight = float(input("Enter weight (kg): "))
#                 height = float(input("Enter height (m): "))
#                 self.create_user(name, age, gender, weight, height)
#             elif choice == '2':
#                 user_name = input("Enter your username: ")
#                 user = self.get_user(user_name)
#                 if user:
#                     self.user_menu(user)
#                 else:
#                     print("User not found. Please create an account first.")
#             elif choice == '3':
#                 print("Exiting Fitness App. Goodbye!")
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#
#     def user_menu(self, user):
#         while True:
#             print(f"\n--- {user.name}'s Menu ---")
#             print("1. View Profile")
#             print("2. Log Activity")
#             print("3. View Activity Log")
#             print("4. Set Goal")
#             print("5. View Goals")
#             print("6. View Dashboard")
#             print("7. Back to Main Menu")
#             choice = input("Enter your choice: ")
#
#             if choice == '1':
#                 print(user)
#             elif choice == '2':
#                 activity_type = input("Enter activity type (e.g., running, swimming): ")
#                 duration = int(input("Enter duration in minutes: "))
#                 calories_burned = float(input("Enter calories burned: "))
#                 user.log_activity(activity_type, duration, calories_burned)
#             elif choice == '3':
#                 user.view_activity_log()
#             elif choice == '4':
#                 goal_type = input("Enter goal type (e.g., weight loss, steps): ")
#                 target_value = input("Enter target value: ")
#                 user.set_goal(goal_type, target_value)
#             elif choice == '5':
#                 user.view_goals()
#             elif choice == '6':
#                 self.display_dashboard(user.name)
#             elif choice == '7':
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#
# if __name__ == "__main__":
#     app = FitnessApp()
#     app.run()
# ```
# CodeReviewerAgent > *   **Input Validation:** The code lacks robust input validation for user creation and activity logging. For instance, `int(input("Enter age: "))` will crash if the user enters non-numeric input. Similarly, `float(input("Enter weight (kg): "))` and `float(input("Enter height (m): "))` will fail on invalid input. It would be better to use a `try-except` block to handle `ValueError` and prompt the user again.
# *   **BMI Calculation Edge Case:** The `calculate_bmi` method correctly handles `self.height <= 0`. However, if the user enters a non-positive height, the `get_bmi_category` method receives a string and returns it. While this prevents a crash, it might be more user-friendly to display an error message directly or handle the string return more explicitly within `get_bmi_category`.
# *   **Type Hinting:** Adding type hints (e.g., `name: str`, `age: int`) to method signatures would improve code readability and maintainability, especially for larger projects.
# *   **Error Handling in `set_goal`:** The `set_goal` method takes `target_value` as a string. Depending on the `goal_type`, it might be beneficial to convert `target_value` to a more appropriate type (e.g., `float` for weight loss, `int` for steps) if possible, or at least include a note or validation for expected types.
# *   **Separation of Concerns (UI vs. Logic):** The `FitnessApp` class handles both the user interface (menu, input prompts) and the core application logic (managing users, logging activities). For larger applications, separating these concerns into different classes or modules (e.g., a `UI` class) would lead to cleaner and more maintainable code.
# *   **Magic Numbers/Strings:** The BMI thresholds (18.5, 24.9, etc.) and menu choices ('1', '2', etc.) are hardcoded. Defining these as constants at the beginning of the script or within the relevant classes would improve readability and make it easier to modify them later.
# *   **Date Handling in `log_activity`:** While `datetime.date.today()` is used when no date is provided, it might be useful to allow users to input a specific date for logging activities, and to validate that input as well.
# *   **BMI Calculation Formatting:** The `__str__` method formats the BMI to two decimal places using `{self.calculate_bmi():.2f}`. This is good, but it assumes `calculate_bmi` will always return a number. If `calculate_bmi` returns a string (e.g., "Height must be positive."), this formatting will cause a `TypeError`. This could be addressed by checking the return type of `calculate_bmi` before formatting.
# CodeRefactorerAgent > ```python
# import datetime
# from typing import Dict, List, Any, Optional, Union
#
# # Constants for BMI categories
# BMI_UNDERWEIGHT_LIMIT = 18.5
# BMI_NORMAL_WEIGHT_UPPER_LIMIT = 24.9
# BMI_OVERWEIGHT_UPPER_LIMIT = 29.9
#
# # Constants for menu options
# MENU_CREATE_USER = '1'
# MENU_LOGIN_SELECT_USER = '2'
# MENU_EXIT = '3'
#
# USER_MENU_VIEW_PROFILE = '1'
# USER_MENU_LOG_ACTIVITY = '2'
# USER_MENU_VIEW_ACTIVITY_LOG = '3'
# USER_MENU_SET_GOAL = '4'
# USER_MENU_VIEW_GOALS = '5'
# USER_MENU_VIEW_DASHBOARD = '6'
# USER_MENU_BACK_TO_MAIN = '7'
#
# class User:
#     """Represents a user in the fitness application."""
#
#     def __init__(self, name: str, age: int, gender: str, weight: float, height: float):
#         """
#         Initializes a User object.
#
#         Args:
#             name: The name of the user.
#             age: The age of the user.
#             gender: The gender of the user.
#             weight: The weight of the user in kilograms.
#             height: The height of the user in meters.
#         """
#         if not isinstance(name, str) or not name:
#             raise ValueError("Name must be a non-empty string.")
#         if not isinstance(age, int) or age <= 0:
#             raise ValueError("Age must be a positive integer.")
#         if not isinstance(gender, str) or not gender:
#             raise ValueError("Gender must be a non-empty string.")
#         if not isinstance(weight, (int, float)) or weight <= 0:
#             raise ValueError("Weight must be a positive number.")
#         if not isinstance(height, (int, float)) or height <= 0:
#             raise ValueError("Height must be a positive number.")
#
#         self.name: str = name
#         self.age: int = age
#         self.gender: str = gender
#         self.weight: float = float(weight)  # in kg
#         self.height: float = float(height)  # in meters
#         self.activity_log: List[Dict[str, Any]] = []
#         self.goals: Dict[str, Any] = {}
#
#     def calculate_bmi(self) -> Union[float, str]:
#         """
#         Calculates the Body Mass Index (BMI).
#
#         Returns:
#             The calculated BMI as a float, or an error message string if height is invalid.
#         """
#         if self.height <= 0:
#             return "Height must be positive."
#         return self.weight / (self.height ** 2)
#
#     def get_bmi_category(self) -> str:
#         """
#         Determines the BMI category based on the calculated BMI.
#
#         Returns:
#             A string representing the BMI category (e.g., "Underweight", "Normal weight").
#         """
#         bmi = self.calculate_bmi()
#         if isinstance(bmi, str):
#             return bmi  # Return the error message if BMI calculation failed
#
#         if bmi < BMI_UNDERWEIGHT_LIMIT:
#             return "Underweight"
#         elif BMI_UNDERWEIGHT_LIMIT <= bmi < BMI_NORMAL_WEIGHT_UPPER_LIMIT:
#             return "Normal weight"
#         elif BMI_NORMAL_WEIGHT_UPPER_LIMIT <= bmi < BMI_OVERWEIGHT_UPPER_LIMIT:
#             return "Overweight"
#         else:
#             return "Obesity"
#
#     def log_activity(self, activity_type: str, duration: int, calories_burned: float, date: Optional[datetime.date] = None):
#         """
#         Logs a user's activity.
#
#         Args:
#             activity_type: The type of activity (e.g., "running", "swimming").
#             duration: The duration of the activity in minutes.
#             calories_burned: The number of calories burned during the activity.
#             date: The date of the activity. Defaults to today if not provided.
#         """
#         if not isinstance(activity_type, str) or not activity_type:
#             print("Activity type must be a non-empty string.")
#             return
#         if not isinstance(duration, int) or duration <= 0:
#             print("Duration must be a positive integer.")
#             return
#         if not isinstance(calories_burned, (int, float)) or calories_burned < 0:
#             print("Calories burned must be a non-negative number.")
#             return
#
#         if date is None:
#             date = datetime.date.today()
#         elif not isinstance(date, datetime.date):
#             print("Invalid date format. Please use YYYY-MM-DD.")
#             return
#
#         self.activity_log.append({
#             "date": date,
#             "activity_type": activity_type,
#             "duration": duration,  # in minutes
#             "calories_burned": calories_burned
#         })
#         print(f"Activity logged: {activity_type} for {duration} minutes.")
#
#     def view_activity_log(self):
#         """Displays the user's activity log."""
#         if not self.activity_log:
#             print("No activities logged yet.")
#             return
#         print(f"\n--- Activity Log for {self.name} ---")
#         for entry in self.activity_log:
#             print(f"Date: {entry['date']}, Activity: {entry['activity_type']}, Duration: {entry['duration']} mins, Calories: {entry['calories_burned']} kcal")
#         print("----------------------------")
#
#     def set_goal(self, goal_type: str, target_value: Any):
#         """
#         Sets a fitness goal for the user.
#
#         Args:
#             goal_type: The type of goal (e.g., "weight loss", "steps").
#             target_value: The target value for the goal.
#         """
#         if not isinstance(goal_type, str) or not goal_type:
#             print("Goal type must be a non-empty string.")
#             return
#
#         # Attempt to convert target_value to appropriate type if possible
#         try:
#             if goal_type.lower() == "weight loss":
#                 target_value = float(target_value)
#                 if target_value <= 0:
#                     raise ValueError("Weight loss target must be positive.")
#             elif goal_type.lower() == "steps":
#                 target_value = int(target_value)
#                 if target_value <= 0:
#                     raise ValueError("Steps target must be positive.")
#             elif goal_type.lower() == "calories burned":
#                 target_value = float(target_value)
#                 if target_value < 0:
#                     raise ValueError("Calories burned target cannot be negative.")
#             # Add more goal types and their type conversions here
#         except ValueError as e:
#             print(f"Invalid target value for {goal_type}: {e}")
#             return
#
#         self.goals[goal_type] = target_value
#         print(f"Goal set: {goal_type} - {target_value}")
#
#     def view_goals(self):
#         """Displays the user's set goals."""
#         if not self.goals:
#             print("No goals set yet.")
#             return
#         print(f"\n--- Goals for {self.name} ---")
#         for goal_type, target_value in self.goals.items():
#             print(f"{goal_type}: {target_value}")
#         print("--------------------")
#
#     def __str__(self) -> str:
#         """Returns a string representation of the user's profile."""
#         bmi_result = self.calculate_bmi()
#         bmi_display = ""
#         if isinstance(bmi_result, str):
#             bmi_display = bmi_result
#         else:
#             bmi_display = f"{bmi_result:.2f} ({self.get_bmi_category()})"
#
#         return (f"User Profile:\n"
#                 f"  Name: {self.name}\n"
#                 f"  Age: {self.age}\n"
#                 f"  Gender: {self.gender}\n"
#                 f"  Weight: {self.weight} kg\n"
#                 f"  Height: {self.height} m\n"
#                 f"  BMI: {bmi_display}")
#
# class FitnessApp:
#     """Main class for the Fitness Application."""
#
#     def __init__(self):
#         """Initializes the FitnessApp with an empty dictionary for users."""
#         self.users: Dict[str, User] = {}
#
#     def _get_validated_input(self, prompt: str, input_type: Any = str, validation_func: Optional[callable] = None) -> Any:
#         """
#         Helper function to get validated input from the user.
#
#         Args:
#             prompt: The message to display to the user.
#             input_type: The expected type of the input (e.g., int, float).
#             validation_func: An optional function to perform additional validation.
#
#         Returns:
#             The validated user input.
#         """
#         while True:
#             try:
#                 user_input = input(prompt)
#                 if input_type == str:
#                     value = user_input
#                 else:
#                     value = input_type(user_input)
#
#                 if validation_func:
#                     if not validation_func(value):
#                         print("Invalid input. Please try again.")
#                         continue
#                 return value
#             except ValueError:
#                 print(f"Invalid input. Please enter a valid {input_type.__name__}.")
#             except Exception as e:
#                 print(f"An unexpected error occurred: {e}. Please try again.")
#
#     def create_user(self) -> None:
#         """Handles the creation of a new user account."""
#         print("\n--- Create New User ---")
#         name = self._get_validated_input("Enter username: ", str)
#         if name in self.users:
#             print(f"User '{name}' already exists.")
#             return
#
#         age = self._get_validated_input("Enter age: ", int, lambda x: x > 0)
#         gender = self._get_validated_input("Enter gender: ", str)
#         weight = self._get_validated_input("Enter weight (kg): ", float, lambda x: x > 0)
#         height = self._get_validated_input("Enter height (m): ", float, lambda x: x > 0)
#
#         try:
#             user = User(name, age, gender, weight, height)
#             self.users[name] = user
#             print(f"User '{name}' created successfully.")
#         except ValueError as e:
#             print(f"Error creating user: {e}")
#
#     def get_user(self, name: str) -> Optional[User]:
#         """
#         Retrieves a user object by their username.
#
#         Args:
#             name: The username of the user to retrieve.
#
#         Returns:
#             The User object if found, otherwise None.
#         """
#         return self.users.get(name)
#
#     def display_dashboard(self, user: User) -> None:
#         """
#         Displays the user's dashboard.
#
#         Args:
#             user: The User object for whom to display the dashboard.
#         """
#         print(f"\n=== Dashboard for {user.name} ===")
#         print(user)
#         user.view_goals()
#         user.view_activity_log()
#         print("============================")
#
#     def run(self) -> None:
#         """Starts the main application loop."""
#         while True:
#             print("\n--- Fitness App Menu ---")
#             print("1. Create User")
#             print("2. Login/Select User")
#             print("3. Exit")
#             choice = input("Enter your choice: ")
#
#             if choice == MENU_CREATE_USER:
#                 self.create_user()
#             elif choice == MENU_LOGIN_SELECT_USER:
#                 user_name = input("Enter your username: ")
#                 user = self.get_user(user_name)
#                 if user:
#                     self.user_menu(user)
#                 else:
#                     print("User not found. Please create an account first.")
#             elif choice == MENU_EXIT:
#                 print("Exiting Fitness App. Goodbye!")
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#
#     def user_menu(self, user: User) -> None:
#         """Displays the menu for a logged-in user."""
#         while True:
#             print(f"\n--- {user.name}'s Menu ---")
#             print("1. View Profile")
#             print("2. Log Activity")
#             print("3. View Activity Log")
#             print("4. Set Goal")
#             print("5. View Goals")
#             print("6. View Dashboard")
#             print("7. Back to Main Menu")
#             choice = input("Enter your choice: ")
#
#             if choice == USER_MENU_VIEW_PROFILE:
#                 print(user)
#             elif choice == USER_MENU_LOG_ACTIVITY:
#                 activity_type = self._get_validated_input("Enter activity type (e.g., running, swimming): ", str)
#                 duration = self._get_validated_input("Enter duration in minutes: ", int, lambda x: x > 0)
#                 calories_burned = self._get_validated_input("Enter calories burned: ", float, lambda x: x >= 0)
#                 date_str = input("Enter date (YYYY-MM-DD, leave blank for today): ")
#                 log_date = None
#                 if date_str:
#                     try:
#                         log_date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
#                     except ValueError:
#                         print("Invalid date format. Using today's date.")
#                 user.log_activity(activity_type, duration, calories_burned, log_date)
#             elif choice == USER_MENU_VIEW_ACTIVITY_LOG:
#                 user.view_activity_log()
#             elif choice == USER_MENU_SET_GOAL:
#                 goal_type = self._get_validated_input("Enter goal type (e.g., weight loss, steps, calories burned): ", str)
#                 target_value = input("Enter target value: ")
#                 user.set_goal(goal_type, target_value)
#             elif choice == USER_MENU_VIEW_GOALS:
#                 user.view_goals()
#             elif choice == USER_MENU_VIEW_DASHBOARD:
#                 self.display_dashboard(user)
#             elif choice == USER_MENU_BACK_TO_MAIN:
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#
# if __name__ == "__main__":
#     app = FitnessApp()
#     app.run()
# ```

# %% [markdown]
# ## Parallel Workflows - Independent Researchers

# %% [markdown]
# 1.   Tech Researcher - Researches AI/ML news and trends
# 2.   Health Researcher - Researches recent medical news and trends
#
#
# 1.   Finance Researcher - Researches finance and fintech news and trends
# 2.   Aggregator Agent - Combines all research findings into a single summary

# %%
# Create tech_researcher agent: Focuses on AI and ML trends.

tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Creat health_researcher agent: Focuses on medical breakthroughs.

health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Create finance_researcher: Focuses on fintech trends.

finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.

aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}

    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}

    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# Create parellel and sequential agents.

# The ParallelAgent runs all its sub-agents simultaneously.

parallel_agent = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher]
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.

root_agent = SequentialAgent(
    name="ResearchPipeline",
    sub_agents=[parallel_agent, aggregator_agent]
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
# Create run time environment and run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > The latest AI/ML trends highlight advancements in **multimodal AI**, **agentic AI**, and **open-source AI**. Multimodal AI integrates various data types (text, audio, visual) for more nuanced understanding and interaction. Agentic AI focuses on proactive, autonomous agents capable of independent action, a shift from reactive systems. Open-source AI fosters global collaboration and transparency by allowing free use and modification of code.
#
# Key companies heavily involved include **Google** (Gemini, Vertex AI, DeepMind), **OpenAI** (ChatGPT), **Microsoft** (Azure AI, Copilot), **Amazon** (AWS, Alexa), **Meta**, and **Apple**. NVIDIA is also crucial for GPU development powering these advancements.
#
# The potential impact is transformative, enhancing human-computer interaction, automating complex tasks, and accelerating innovation across industries like healthcare and finance. However, ethical considerations, data privacy, and the need for skilled talent remain significant challenges.
# FinanceResearcher > Here's a daily executive briefing for Tech, Health, and Finance:
#
# **Tech:** Artificial Intelligence (AI) in healthcare is a key trend, focusing on building trust amidst regulatory uncertainty. Organizations must manage risks proactively and ensure AI enhances, rather than replaces, human roles. The market implication is a cautious but growing adoption of AI for clinical support, with a future outlook of AI becoming more integrated as trust and frameworks develop.
#
# **Health:** The digital health and health tech sectors are experiencing accelerated transformation due to fragmented regulations. Companies are seeking innovative solutions while balancing financial and regulatory risks. Market implications include intense competition and a search for emerging leaders. The future suggests a market consolidation as clear leaders and proven models gain traction.
#
# **Finance:** Financial reporting for institutions is evolving beyond traditional methods. There's a growing need for executive-level briefings that provide clarity and actionable insights quickly. Market implications involve a demand for streamlined financial data analysis tools. The future outlook points to increased adoption of AI-driven financial analytics and personalized reporting for faster, sharper decision-making.
# HealthResearcher > **Health:**
# *   **AI-powered diagnostics:** Artificial intelligence is increasingly being used to analyze medical images and patient data for faster, more accurate diagnoses of diseases like sepsis and cancer. Its market is projected to reach $614 billion by 2034, with applications already enhancing diagnosis and treatment plans.
# *   **Gene Therapy:** This involves introducing genetic material to treat or prevent disease. First trialed in 1990, it's now used for blindness and holds promise for heart disease, hemophilia, and cystic fibrosis.
# *   **RSV Vaccines:** The FDA has approved new vaccines targeting Respiratory Syncytial Virus, significantly reducing deaths and hospitalizations in older adults and protecting children.
#
# **Technology:**
# *   **Agentic AI:** Evolving beyond AI assistants, these agents can autonomously plan and execute complex workflows, with the autonomous AI market projected to hit $11.79 billion by 2026.
# *   **Quantum Computing:** While still in development, practical applications are emerging in logistics, finance, and pharmaceuticals. Significant advancements in qubit stability and algorithms suggest potential for revolutionizing data processing and cryptography.
# *   **Spatial Computing & XR:** Merging physical and digital realities, this technology is moving into essential workspaces for training, design, and remote support, with XR headset shipments expected to rise 87% in 2026.
#
# **Finance:**
# *   **AI in Financial Services:** Generative AI and advanced machine learning are transforming risk assessment, customer interactions, and personalized financial planning. The AI market in finance is rapidly growing, with potential to boost productivity and enhance decision-making.
# *   **Blockchain and Tokenization:** The increasing adoption of tokenized real-world assets on blockchains, projected to reach $2 trillion by 2028, is reshaping global finance.
# *   **Post-Quantum Cryptography:** With quantum computers posing a threat to current encryption, a transition to post-quantum cryptography is underway, with some solutions already deployable. This migration is crucial for securing financial transactions.
#
# **Estimated Timelines:**
# *   **AI-powered diagnostics and Agentic AI:** Already being implemented, with significant growth expected within the next 1-3 years.
# *   **Quantum Computing:** Practical applications are emerging now, with further significant advancements and broader utility expected within the next 5-10 years.
# *   **Post-Quantum Cryptography:** Migration is ongoing and expected to accelerate rapidly over the next 5 years.
# AggregatorAgent > ## Executive Summary: Converging Innovations in Tech, Health, and Finance
#
# **Key Takeaway:** AI, particularly agentic and multimodal capabilities, is the central, unifying force driving rapid innovation and transformation across technology, healthcare, and finance. While promising immense benefits, its integration necessitates careful navigation of ethical, regulatory, and talent challenges.
#
# **Common Themes & Surprising Connections:**
#
# *   **AI as the Engine:** All three sectors are experiencing profound shifts driven by advancements in AI. From AI-powered diagnostics in healthcare and agentic AI for complex workflows in technology, to generative AI revolutionizing financial services, AI's impact is pervasive and accelerating. The trend towards autonomous agents (agentic AI) is particularly notable, promising proactive and independent systems across domains.
# *   **Data-Driven Transformation:** The ability to process and interpret vast amounts of diverse data (multimodal AI) is critical. In healthcare, this means faster diagnoses from medical images and patient data. In finance, it leads to enhanced risk assessment and personalized planning.
# *   **Navigating Disruption:** Each sector faces significant disruption, with AI and emerging technologies like quantum computing (tech/finance) and gene therapy (health) pushing boundaries. However, this innovation is tempered by common challenges: regulatory uncertainty (especially in tech and health), the need for trust, and the critical importance of security (e.g., post-quantum cryptography in finance).
# *   **Market Dynamism:** Across all fields, there's an observed trend towards consolidation and the emergence of clear leaders as proven models gain traction. Open-source AI further fuels this by fostering global collaboration and accelerating development.
#
# **Most Important Insights:**
#
# 1.  **AI's Autonomous Future:** Agentic AI is poised to move beyond assistive roles to autonomous execution of complex tasks, with significant near-term growth and market implications.
# 2.  **Interconnected Security Imperatives:** The rise of quantum computing necessitates a proactive transition to post-quantum cryptography, a critical security measure for financial transactions and data integrity across all sectors.
# 3.  **Trust and Regulation as Key Enablers:** Building trust and establishing clear regulatory frameworks are paramount for the widespread adoption of AI in healthcare and for navigating the competitive landscape of digital health.
#
# The convergence of advanced AI, coupled with breakthroughs in areas like gene therapy and quantum computing, presents a future of unprecedented innovation. However, realizing this potential hinges on effectively managing the associated risks, ensuring ethical deployment, and fostering the necessary talent and trust.

# %% [markdown]
# ## Loop Workflows - The Refinement Cycle

# %% [markdown]
# Iterative Story Refinement
#
# 1.   Writer Agent - Writes a draft of a short story
# 2.   Critic Agent - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.

initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 10000-15000 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.

critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}

    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.

def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.

refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.

    Story Draft: {current_story}
    Critique: {critique}

    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.

story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.

root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
# Create a runner and run the root agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, his beard a frosted white against the salt-worn timbers of the lighthouse, polished the massive lens. For thirty years, the sea and sky had been his only companions, their moods more predictable than human folk. Tonight, however, was different. A storm raged, a fury of wind and wave that rattled his bones.
#
# Amidst the chaos, a shard of emerald light pulsed from the seabed, visible even through the tempest’s spray. He scrambled down the winding stairs, his heart thrumming. There, lodged in the rocks, was not a piece of wreckage, but a smooth, obsidian tablet. As he touched it, intricate lines of pure, vibrant light bloomed across its surface, forming a map of stars he’d never seen.
# CriticAgent > The plot sets up an intriguing mystery with the discovery of the obsidian tablet and its celestial map. The character of Elias is established as a solitary, experienced lighthouse keeper, making his fascination with the unknown object believable. The pacing is good, quickly moving from the storm's intensity to the discovery.
#
# Here are a few suggestions for improvement:
#
# 1.  **Elaborate on Elias's reaction and immediate thoughts:** While his heart thrums, it would be beneficial to delve slightly deeper into his immediate internal reaction. Is it fear, awe, scientific curiosity, or a sense of destiny? Showing a brief flicker of his thought process as he encounters the alien star map could enhance his characterization and the reader's connection to his experience.
# 2.  **Hint at the implications of the map:** The map shows "stars he'd never seen." This is a great hook. Consider adding a sentence or two that hints at what this discovery *could* mean. Is it a navigation chart to another world, a prophecy, or something else entirely? Even a subtle suggestion can raise the stakes and draw the reader further into the mystery.
# 3.  **Strengthen the sensory details of the tablet:** Beyond the glowing lines, the description of the obsidian tablet could be more evocative. What does it feel like to the touch? Is it cold, warm, smooth, or does it have a subtle texture? Adding a brief sensory detail beyond the visual would make the discovery more tangible.
# RefinerAgent > Elias, his beard a frosted white against the salt-worn timbers of the lighthouse, polished the massive lens. For thirty years, the sea and sky had been his only companions, their moods more predictable than human folk. Tonight, however, was different. A storm raged, a fury of wind and wave that rattled his bones.
#
# Amidst the chaos, a shard of emerald light pulsed from the seabed, visible even through the tempest’s spray. He scrambled down the winding stairs, his heart thrumming with a mixture of awe and a primal fear he hadn’t felt since his first night at sea. There, lodged in the rocks, was not a piece of wreckage, but a smooth, obsidian tablet. As his calloused fingers brushed against its surface, it felt unnervingly warm, like a living thing. Intricate lines of pure, vibrant light bloomed across its surface, forming a map of stars he’d never seen. His breath hitched. This was no mere celestial chart; it felt like an invitation, a key to a destiny far grander and more terrifying than his solitary life had ever promised.
# CriticAgent > APPROVED
