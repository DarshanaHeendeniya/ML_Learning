# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshanaHeendeniya/ML_Learning/blob/main/Day1_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authenticate in the Note book

import os
from google.colab import userdata
import google.generativeai as genai

try:
  GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
  os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # For libraries that rely on env var
  genai.configure(api_key=GOOGLE_API_KEY)
  print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %%
# Import the specific components from the Agent Development Kit and the Generative AI library.

from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Configure retry options

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.

research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.

summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.

root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
# Create the ochestrating environment (runner) and run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Here's a summary of the latest advancements in quantum computing and their implications for AI:
#
# *   **Revolutionary Computational Power:** Quantum computing, with its ability to use qubits for superposition, offers exponential speedups for complex calculations, enabling faster AI model training and the tackling of previously intractable problems like optimization and simulation.
# *   **Advancements in Quantum Machine Learning (QML):** QML integrates quantum algorithms into AI, promising dramatic improvements in learning speed, data processing efficiency, and the acceleration of tasks like deep learning training.
# *   **Solving Complex and "NP-hard" Problems:** Quantum AI is expected to unlock solutions in fields such as drug discovery, materials science, logistics, finance, and cybersecurity by efficiently solving computationally intensive problems.
# *   **Potential for More Robust and Energy-Efficient AI:** Quantum neural networks may lead to faster learning and more resilient AI models, with early research suggesting significant energy efficiency gains compared to classical AI.
# *   **Emerging Challenges and Synergies:** While not all AI aspects may be universally boosted (e.g., large datasets), and challenges in information processing and probabilistic outputs exist, AI is also being used to improve quantum systems (e.g., error correction). Significant investment and ongoing developments point to a powerful future for "Quantum AI."

# %% [markdown]
# ## Sequential Workflows - The Assembly Line

# %% [markdown]
# Blog Post Creation with Sequential Agents
#
#
#
# 1.   Outline Agent - Creates a blog outline for a given topic
# 2.   Writer Agent - Writes a blog post
#
#
# 1.   Editor Agent - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.

outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.

writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.

editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
# Create root agent. Root agent is a sequential agent which runs it sub agents in the order they are listed.

root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
# Run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Blog Outline: The Multi-Agent Advantage: Supercharging Your Software Development
#
# ### Introduction Hook:
#
# Feeling overwhelmed by increasingly complex software projects? Are you looking for ways to build more robust, scalable, and intelligent applications without reinventing the wheel? Imagine a team of specialized, intelligent assistants working collaboratively behind the scenes to handle the heavy lifting. That's the power of multi-agent systems (MAS), and it's about to revolutionize how you develop software.
#
# ### Main Sections:
#
# **1. What Exactly Are Multi-Agent Systems? Breaking Down the Basics**
#
# *   **Definition:** Understand MAS as a collection of autonomous agents that interact with each other and their environment to achieve individual or collective goals.
# *   **Key Characteristics:** Explore concepts like autonomy, proactivity, reactivity, and social ability in the context of software agents.
# *   **Why Now?** Discuss the increasing relevance of MAS due to the growth of distributed systems, AI, and the need for more sophisticated software solutions.
#
# **2. The Power of Specialization: How Agents Tackle Complexity**
#
# *   **Modular Design:** Learn how MAS promotes breaking down complex problems into smaller, manageable sub-problems, each handled by a specialized agent.
# *   **Reusability and Abstraction:** Discover how agents can be designed as reusable components, abstracting away intricate logic and simplifying integration.
# *   **Enhanced Maintainability:** Understand how isolating functionality within agents makes debugging and updates more targeted and less prone to cascading failures.
#
# **3. Boosting Efficiency and Performance: Smarter, Faster Software**
#
# *   **Parallel Processing and Distribution:** Explore how MAS can leverage distributed computing power, with agents operating concurrently to speed up task execution.
# *   **Intelligent Resource Management:** See how agents can dynamically adapt to changing resource availability, optimizing performance and preventing bottlenecks.
# *   **Self-Optimization and Adaptation:** Discuss how MAS can learn from their environment and interactions, continuously improving their performance over time.
#
# **4. Building Resilient and Scalable Applications: The Future-Proof Approach**
#
# *   **Fault Tolerance and Robustness:** Understand how the distributed nature of MAS makes them inherently more resilient to individual agent failures.
# *   **Seamless Scalability:** Learn how easily new agents can be added to a system to handle increased load or new functionalities without major architectural overhauls.
# *   **Agility in a Dynamic World:** Discover how MAS can be quickly reconfigured or adapted to respond to evolving business requirements or environmental changes.
#
# ### Concluding Thought:
#
# Embracing multi-agent systems isn't just about adopting a new technology; it's about adopting a new paradigm for software development. By harnessing the collective intelligence and specialized capabilities of autonomous agents, you can unlock unprecedented levels of efficiency, scalability, and robustness in your applications, paving the way for the next generation of intelligent software.
# WriterAgent > ## The Multi-Agent Advantage: Supercharging Your Software Development
#
# Feeling overwhelmed by increasingly complex software projects? Are you looking for ways to build more robust, scalable, and intelligent applications without reinventing the wheel? Imagine a team of specialized, intelligent assistants working collaboratively behind the scenes to handle the heavy lifting. That's the power of multi-agent systems (MAS), and it's about to revolutionize how you develop software.
#
# At its core, a MAS is a collection of autonomous agents, each designed to perform specific tasks and interact with each other and their environment. These aren't just isolated functions; they're intelligent entities that can be proactive, reactive, and socially adept. Why is this approach gaining traction now? The explosion of distributed systems, advancements in AI, and the ever-growing demand for sophisticated software solutions make MAS a timely and potent solution.
#
# The beauty of MAS lies in its embrace of specialization. Complex problems are broken down into smaller, manageable sub-problems, each assigned to a dedicated agent. This modular design not only promotes reusability and abstraction, simplifying integration, but also significantly enhances maintainability. Isolating functionality within agents means debugging and updates are more targeted, dramatically reducing the risk of cascading failures.
#
# Beyond structure, MAS unlocks new levels of efficiency and performance. By enabling parallel processing and distributed computing, agents can execute tasks concurrently, speeding up overall execution. They also excel at intelligent resource management, dynamically adapting to changing conditions to optimize performance and prevent bottlenecks. This adaptability extends to self-optimization; MAS can learn from their interactions, continuously improving their effectiveness over time.
#
# Finally, MAS provides a future-proof approach to building resilient and scalable applications. Their distributed nature inherently offers fault tolerance, as the failure of one agent doesn't cripple the entire system. Adding new agents to handle increased load or new functionalities is remarkably seamless, fostering unparalleled scalability. In our dynamic world, this agility allows applications to be quickly reconfigured and adapted to evolving requirements, ensuring your software stays relevant and robust.
#
# Embracing multi-agent systems isn't just adopting new tech; it's a paradigm shift. By leveraging the collective intelligence and specialized capabilities of autonomous agents, you can build more efficient, scalable, and robust applications, ushering in the next generation of intelligent software.
# EditorAgent > ## The Multi-Agent Advantage: Supercharging Your Software Development
#
# Feeling overwhelmed by increasingly complex software projects? Are you searching for ways to build more robust, scalable, and intelligent applications without starting from scratch? Imagine a team of specialized, intelligent assistants working collaboratively behind the scenes to handle the heavy lifting. That's the power of multi-agent systems (MAS), and this approach is poised to revolutionize your software development process.
#
# At its core, a MAS is a collection of autonomous agents, each designed to perform specific tasks and interact with each other and their environment. These aren't merely isolated functions; they are intelligent entities capable of being proactive, reactive, and socially adept. So, why is this approach gaining traction now? The exponential growth of distributed systems, significant advancements in AI, and the ever-increasing demand for sophisticated software solutions make MAS a timely and potent solution.
#
# The true beauty of MAS lies in its embrace of specialization. Complex problems are elegantly broken down into smaller, manageable sub-problems, with each assigned to a dedicated agent. This modular design not only fosters reusability and abstraction, thereby simplifying integration, but also dramatically enhances maintainability. By isolating functionality within individual agents, debugging and updates become more targeted, significantly reducing the risk of cascading failures.
#
# Beyond structural advantages, MAS unlocks new levels of efficiency and performance. By enabling parallel processing and distributed computing, agents can execute tasks concurrently, accelerating overall execution times. They also excel at intelligent resource management, dynamically adapting to changing conditions to optimize performance and prevent bottlenecks. This adaptability extends to self-optimization; MAS can learn from their interactions, continuously improving their effectiveness over time.
#
# Finally, MAS offers a future-proof approach to building resilient and scalable applications. Their inherent distributed nature provides robust fault tolerance, as the failure of one agent does not cripple the entire system. Adding new agents to handle increased load or incorporate new functionalities is remarkably seamless, fostering unparalleled scalability. In our dynamic world, this agility allows applications to be quickly reconfigured and adapted to evolving requirements, ensuring your software remains relevant and robust.
#
# Embracing multi-agent systems is more than just adopting a new technology; it represents a fundamental paradigm shift in software development. By leveraging the collective intelligence and specialized capabilities of autonomous agents, you can build more efficient, scalable, and robust applications, paving the way for the next generation of intelligent software.

# %%
# Part of agent.py --> Follow https://google.github.io/adk-docs/get-started/quickstart/ to learn the setup

# --- 1. Define Sub-Agents for Each Pipeline Stage ---

# Code Writer Agent
# Takes the initial specification (from user query) and writes code.
code_writer_agent = Agent(
    name="CodeWriterAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction
    instruction="""You are a Python Code Generator.
Based *only* on the user's request, write Python code that fulfills the requirement.
Output *only* the complete Python code block, enclosed in triple backticks (```python ... ```).
Do not add any other text before or after the code block.
""",
    description="Writes initial Python code based on a specification.",
    output_key="generated_code" # Stores output in state['generated_code']
)

# Code Reviewer Agent
# Takes the code generated by the previous agent (read from state) and provides feedback.
code_reviewer_agent = Agent(
    name="CodeReviewerAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction, correctly using state key injection
    instruction="""You are an expert Python Code Reviewer.
    Your task is to provide constructive feedback on the provided code.

    **Code to Review:**
    ```python
    {generated_code}
    ```

**Review Criteria:**
1.  **Correctness:** Does the code work as intended? Are there logic errors?
2.  **Readability:** Is the code clear and easy to understand? Follows PEP 8 style guidelines?
3.  **Efficiency:** Is the code reasonably efficient? Any obvious performance bottlenecks?
4.  **Edge Cases:** Does the code handle potential edge cases or invalid inputs gracefully?
5.  **Best Practices:** Does the code follow common Python best practices?

**Output:**
Provide your feedback as a concise, bulleted list. Focus on the most important points for improvement.
If the code is excellent and requires no changes, simply state: "No major issues found."
Output *only* the review comments or the "No major issues" statement.
""",
    description="Reviews code and provides feedback.",
    output_key="review_comments", # Stores output in state['review_comments']
)


# Code Refactorer Agent
# Takes the original code and the review comments (read from state) and refactors the code.
code_refactorer_agent = Agent(
    name="CodeRefactorerAgent",
    model="gemini-2.5-flash-lite",
    # Change 3: Improved instruction, correctly using state key injection
    instruction="""You are a Python Code Refactoring AI.
Your goal is to improve the given Python code based on the provided review comments.

  **Original Code:**
  ```python
  {generated_code}
  ```

  **Review Comments:**
  {review_comments}

**Task:**
Carefully apply the suggestions from the review comments to refactor the original code.
If the review comments state "No major issues found," return the original code unchanged.
Ensure the final code is complete, functional, and includes necessary imports and docstrings.

**Output:**
Output *only* the final, refactored Python code block, enclosed in triple backticks (```python ... ```).
Do not add any other text before or after the code block.
""",
    description="Refactors code based on review comments.",
    output_key="refactored_code", # Stores output in state['refactored_code']
)


# --- 2. Create the SequentialAgent ---
# This agent orchestrates the pipeline by running the sub_agents in order.
code_pipeline_agent = SequentialAgent(
    name="CodePipelineAgent",
    sub_agents=[code_writer_agent, code_reviewer_agent, code_refactorer_agent],
    description="Executes a sequence of code writing, reviewing, and refactoring.",
    # The agents will run in the order provided: Writer -> Reviewer -> Refactorer
)

# For ADK tools compatibility, the root agent must be named `root_agent`
root_agent = code_pipeline_agent

# Run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a python code to create a fitness app"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a python code to create a fitness app
# CodeWriterAgent > ```python
# import datetime
#
# class User:
#     def __init__(self, name, age, gender):
#         self.name = name
#         self.age = age
#         self.gender = gender
#         self.workouts = []
#         self.goals = {}
#
#     def log_workout(self, workout_type, duration_minutes, calories_burned):
#         workout = {
#             "type": workout_type,
#             "duration_minutes": duration_minutes,
#             "calories_burned": calories_burned,
#             "timestamp": datetime.datetime.now()
#         }
#         self.workouts.append(workout)
#         print(f"Workout logged: {workout_type} for {duration_minutes} minutes.")
#
#     def set_goal(self, goal_type, target_value):
#         self.goals[goal_type] = target_value
#         print(f"Goal set: {goal_type} - {target_value}")
#
#     def view_progress(self):
#         print(f"\n--- Progress for {self.name} ---")
#         if not self.workouts:
#             print("No workouts logged yet.")
#             return
#
#         total_duration = sum(w["duration_minutes"] for w in self.workouts)
#         total_calories = sum(w["calories_burned"] for w in self.workouts)
#
#         print(f"Total workouts logged: {len(self.workouts)}")
#         print(f"Total workout duration: {total_duration} minutes")
#         print(f"Total calories burned: {total_calories} calories")
#
#         for goal_type, target_value in self.goals.items():
#             current_value = 0
#             if goal_type == "weekly_duration":
#                 # Calculate duration for the current week
#                 today = datetime.date.today()
#                 start_of_week = today - datetime.timedelta(days=today.weekday())
#                 weekly_workouts = [w for w in self.workouts if w["timestamp"].date() >= start_of_week]
#                 current_value = sum(w["duration_minutes"] for w in weekly_workouts)
#             elif goal_type == "weekly_calories":
#                 # Calculate calories for the current week
#                 today = datetime.date.today()
#                 start_of_week = today - datetime.timedelta(days=today.weekday())
#                 weekly_workouts = [w for w in self.workouts if w["timestamp"].date() >= start_of_week]
#                 current_value = sum(w["calories_burned"] for w in weekly_workouts)
#             elif goal_type == "total_workouts":
#                 current_value = len(self.workouts)
#             elif goal_type == "total_calories":
#                 current_value = total_calories
#             elif goal_type == "total_duration":
#                 current_value = total_duration
#
#             print(f"  {goal_type.replace('_', ' ').title()}: Current - {current_value}, Target - {target_value}")
#             if current_value >= target_value:
#                 print(f"  Congratulations! You've met your {goal_type.replace('_', ' ')} goal.")
#
# class FitnessApp:
#     def __init__(self):
#         self.users = {}
#
#     def create_user(self, name, age, gender):
#         if name in self.users:
#             print(f"User '{name}' already exists.")
#             return None
#         new_user = User(name, age, gender)
#         self.users[name] = new_user
#         print(f"User '{name}' created successfully.")
#         return new_user
#
#     def get_user(self, name):
#         return self.users.get(name)
#
#     def display_menu(self):
#         print("\n--- Fitness App Menu ---")
#         print("1. Create User")
#         print("2. Log Workout")
#         print("3. Set Goal")
#         print("4. View Progress")
#         print("5. Switch User")
#         print("6. Exit")
#
#     def run(self):
#         current_user = None
#         while True:
#             self.display_menu()
#             choice = input("Enter your choice: ")
#
#             if choice == '1':
#                 name = input("Enter user's name: ")
#                 age = int(input("Enter user's age: "))
#                 gender = input("Enter user's gender: ")
#                 self.create_user(name, age, gender)
#
#             elif choice == '2':
#                 if not current_user:
#                     print("Please select or create a user first.")
#                     continue
#                 workout_type = input("Enter workout type (e.g., running, cycling, weightlifting): ")
#                 duration = int(input("Enter duration in minutes: "))
#                 calories = int(input("Enter calories burned: "))
#                 current_user.log_workout(workout_type, duration, calories)
#
#             elif choice == '3':
#                 if not current_user:
#                     print("Please select or create a user first.")
#                     continue
#                 print("Available goal types: weekly_duration, weekly_calories, total_workouts, total_calories, total_duration")
#                 goal_type = input("Enter goal type: ")
#                 target_value = int(input("Enter target value: "))
#                 current_user.set_goal(goal_type, target_value)
#
#             elif choice == '4':
#                 if not current_user:
#                     print("Please select or create a user first.")
#                     continue
#                 current_user.view_progress()
#
#             elif choice == '5':
#                 user_name = input("Enter the name of the user to switch to: ")
#                 user = self.get_user(user_name)
#                 if user:
#                     current_user = user
#                     print(f"Switched to user: {current_user.name}")
#                 else:
#                     print(f"User '{user_name}' not found.")
#
#             elif choice == '6':
#                 print("Exiting Fitness App. Goodbye!")
#                 break
#
#             else:
#                 print("Invalid choice. Please try again.")
#
# if __name__ == "__main__":
#     app = FitnessApp()
#     app.run()
# ```
# CodeReviewerAgent > *   **Input Validation:** The code assumes valid integer inputs for age, duration, calories, and target values. It would be more robust to include `try-except` blocks to handle `ValueError` if the user enters non-integer input.
# *   **Date Handling in `view_progress`:** The calculation for `start_of_week` is correct, but it's repeated in both `weekly_duration` and `weekly_calories` checks. This could be extracted into a helper method or calculated once before the loop for better readability and maintainability.
# *   **Redundant `print` Statements:** The `User.log_workout` and `User.set_goal` methods both print confirmation messages. While this is useful for immediate feedback, in a larger application, you might want to separate the logic from the UI and return values instead of printing directly, allowing the caller to decide how to present the information.
# *   **Magic Strings for Goal Types:** The `view_progress` method uses string literals ("weekly\_duration", "weekly\_calories", etc.) to identify goal types. Using constants or an Enum for these goal types would make the code less prone to typos and easier to manage if goal types change.
# *   **No Error Handling for `datetime.datetime.now()`:** While unlikely to fail, it's good practice to be aware that operations involving external modules like `datetime` could potentially raise exceptions. For this specific case, it's not a significant concern.
# *   **User Creation Duplication:** The `create_user` method handles existing users by printing a message and returning `None`. This is acceptable, but depending on the desired user experience, you might want to throw an exception or return a specific status code.
# *   **Hardcoded Menu Options:** The menu options and their corresponding actions are hardcoded within the `run` method. For a more extensible application, consider using a dictionary or a more structured approach to map choices to functions.
# CodeRefactorerAgent > ```python
# import datetime
# from enum import Enum
#
# class GoalType(Enum):
#     WEEKLY_DURATION = "weekly_duration"
#     WEEKLY_CALORIES = "weekly_calories"
#     TOTAL_WORKOUTS = "total_workouts"
#     TOTAL_CALORIES = "total_calories"
#     TOTAL_DURATION = "total_duration"
#
# class User:
#     """Represents a user in the fitness application."""
#
#     def __init__(self, name: str, age: int, gender: str):
#         """
#         Initializes a User object.
#
#         Args:
#             name: The name of the user.
#             age: The age of the user.
#             gender: The gender of the user.
#         """
#         if not isinstance(age, int) or age <= 0:
#             raise ValueError("Age must be a positive integer.")
#         self.name = name
#         self.age = age
#         self.gender = gender
#         self.workouts = []
#         self.goals = {}
#
#     def log_workout(self, workout_type: str, duration_minutes: int, calories_burned: int) -> dict:
#         """
#         Logs a workout session for the user.
#
#         Args:
#             workout_type: The type of workout (e.g., running, cycling).
#             duration_minutes: The duration of the workout in minutes.
#             calories_burned: The number of calories burned during the workout.
#
#         Returns:
#             A dictionary representing the logged workout.
#         """
#         if not isinstance(duration_minutes, int) or duration_minutes <= 0:
#             raise ValueError("Duration must be a positive integer.")
#         if not isinstance(calories_burned, int) or calories_burned < 0:
#             raise ValueError("Calories burned must be a non-negative integer.")
#
#         workout = {
#             "type": workout_type,
#             "duration_minutes": duration_minutes,
#             "calories_burned": calories_burned,
#             "timestamp": datetime.datetime.now()
#         }
#         self.workouts.append(workout)
#         return workout
#
#     def set_goal(self, goal_type: GoalType, target_value: int) -> None:
#         """
#         Sets a fitness goal for the user.
#
#         Args:
#             goal_type: The type of goal (from GoalType Enum).
#             target_value: The target value for the goal.
#         """
#         if not isinstance(target_value, int) or target_value <= 0:
#             raise ValueError("Target value must be a positive integer.")
#         if not isinstance(goal_type, GoalType):
#             raise TypeError("goal_type must be an instance of GoalType Enum.")
#
#         self.goals[goal_type] = target_value
#
#     def _get_start_of_week(self) -> datetime.date:
#         """Helper method to get the start of the current week."""
#         today = datetime.date.today()
#         return today - datetime.timedelta(days=today.weekday())
#
#     def view_progress(self) -> None:
#         """Displays the user's workout progress and goal achievements."""
#         print(f"\n--- Progress for {self.name} ---")
#         if not self.workouts:
#             print("No workouts logged yet.")
#             return
#
#         total_duration = sum(w["duration_minutes"] for w in self.workouts)
#         total_calories = sum(w["calories_burned"] for w in self.workouts)
#
#         print(f"Total workouts logged: {len(self.workouts)}")
#         print(f"Total workout duration: {total_duration} minutes")
#         print(f"Total calories burned: {total_calories} calories")
#
#         start_of_week = self._get_start_of_week()
#
#         for goal_type, target_value in self.goals.items():
#             current_value = 0
#             weekly_workouts = [
#                 w for w in self.workouts if w["timestamp"].date() >= start_of_week
#             ]
#
#             if goal_type == GoalType.WEEKLY_DURATION:
#                 current_value = sum(w["duration_minutes"] for w in weekly_workouts)
#             elif goal_type == GoalType.WEEKLY_CALORIES:
#                 current_value = sum(w["calories_burned"] for w in weekly_workouts)
#             elif goal_type == GoalType.TOTAL_WORKOUTS:
#                 current_value = len(self.workouts)
#             elif goal_type == GoalType.TOTAL_CALORIES:
#                 current_value = total_calories
#             elif goal_type == GoalType.TOTAL_DURATION:
#                 current_value = total_duration
#
#             goal_display_name = goal_type.value.replace('_', ' ').title()
#             print(f"  {goal_display_name}: Current - {current_value}, Target - {target_value}")
#             if current_value >= target_value:
#                 print(f"  Congratulations! You've met your {goal_type.value.replace('_', ' ')} goal.")
#
# class FitnessApp:
#     """Main class for the Fitness Application."""
#
#     def __init__(self):
#         self.users = {}
#         self.current_user = None
#         self.menu_actions = {
#             "1": self.create_user_prompt,
#             "2": self.log_workout_prompt,
#             "3": self.set_goal_prompt,
#             "4": self.view_progress_prompt,
#             "5": self.switch_user_prompt,
#             "6": lambda: print("Exiting Fitness App. Goodbye!") # Exit action
#         }
#
#     def create_user(self, name: str, age: int, gender: str) -> User | None:
#         """
#         Creates a new user if the name does not already exist.
#
#         Args:
#             name: The name of the user.
#             age: The age of the user.
#             gender: The gender of the user.
#
#         Returns:
#             The created User object, or None if the user already exists.
#         """
#         if name in self.users:
#             print(f"User '{name}' already exists.")
#             return None
#         try:
#             new_user = User(name, age, gender)
#             self.users[name] = new_user
#             print(f"User '{name}' created successfully.")
#             return new_user
#         except ValueError as e:
#             print(f"Error creating user: {e}")
#             return None
#
#     def get_user(self, name: str) -> User | None:
#         """
#         Retrieves a user by their name.
#
#         Args:
#             name: The name of the user to retrieve.
#
#         Returns:
#             The User object if found, otherwise None.
#         """
#         return self.users.get(name)
#
#     def display_menu(self) -> None:
#         """Displays the main menu options."""
#         print("\n--- Fitness App Menu ---")
#         print("1. Create User")
#         print("2. Log Workout")
#         print("3. Set Goal")
#         print("4. View Progress")
#         print("5. Switch User")
#         print("6. Exit")
#
#     def _get_validated_input(self, prompt: str, input_type: type = str, validation_func=None):
#         """Helper to get validated user input."""
#         while True:
#             try:
#                 user_input = input(prompt)
#                 value = input_type(user_input)
#                 if validation_func and not validation_func(value):
#                     print("Invalid input. Please try again.")
#                     continue
#                 return value
#             except ValueError:
#                 print(f"Invalid input. Please enter a valid {input_type.__name__}.")
#             except TypeError:
#                 print(f"Invalid input type. Please enter a valid {input_type.__name__}.")
#
#     def create_user_prompt(self):
#         """Handles the user interaction for creating a new user."""
#         name = self._get_validated_input("Enter user's name: ")
#         age = self._get_validated_input("Enter user's age: ", int, lambda x: x > 0)
#         gender = self._get_validated_input("Enter user's gender: ")
#         self.create_user(name, age, gender)
#
#     def log_workout_prompt(self):
#         """Handles the user interaction for logging a workout."""
#         if not self.current_user:
#             print("Please select or create a user first.")
#             return
#         workout_type = self._get_validated_input("Enter workout type (e.g., running, cycling, weightlifting): ")
#         duration = self._get_validated_input("Enter duration in minutes: ", int, lambda x: x > 0)
#         calories = self._get_validated_input("Enter calories burned: ", int, lambda x: x >= 0)
#         try:
#             logged_workout = self.current_user.log_workout(workout_type, duration, calories)
#             print(f"Workout logged: {logged_workout['type']} for {logged_workout['duration_minutes']} minutes.")
#         except ValueError as e:
#             print(f"Error logging workout: {e}")
#
#     def set_goal_prompt(self):
#         """Handles the user interaction for setting a goal."""
#         if not self.current_user:
#             print("Please select or create a user first.")
#             return
#
#         print("Available goal types:")
#         for gt in GoalType:
#             print(f"- {gt.value}")
#
#         goal_type_str = self._get_validated_input("Enter goal type: ")
#         try:
#             goal_type = GoalType(goal_type_str)
#             target_value = self._get_validated_input("Enter target value: ", int, lambda x: x > 0)
#             self.current_user.set_goal(goal_type, target_value)
#             print(f"Goal set: {goal_type.value.replace('_', ' ').title()} - {target_value}")
#         except ValueError:
#             print(f"Invalid goal type '{goal_type_str}'. Please choose from the available types.")
#         except TypeError as e:
#             print(f"Error setting goal: {e}")
#
#
#     def view_progress_prompt(self):
#         """Handles the user interaction for viewing progress."""
#         if not self.current_user:
#             print("Please select or create a user first.")
#             return
#         self.current_user.view_progress()
#
#     def switch_user_prompt(self):
#         """Handles the user interaction for switching the current user."""
#         user_name = self._get_validated_input("Enter the name of the user to switch to: ")
#         user = self.get_user(user_name)
#         if user:
#             self.current_user = user
#             print(f"Switched to user: {self.current_user.name}")
#         else:
#             print(f"User '{user_name}' not found.")
#
#     def run(self) -> None:
#         """Runs the main application loop."""
#         while True:
#             self.display_menu()
#             choice = input("Enter your choice: ")
#
#             action = self.menu_actions.get(choice)
#             if action:
#                 if choice == '6':  # Exit
#                     action()
#                     break
#                 action()
#             else:
#                 print("Invalid choice. Please try again.")
#
# if __name__ == "__main__":
#     app = FitnessApp()
#     app.run()
# ```

# %% [markdown]
# ## Parallel Workflows - Independent Researchers

# %% [markdown]
# 1.   Tech Researcher - Researches AI/ML news and trends
# 2.   Health Researcher - Researches recent medical news and trends
#
#
# 1.   Finance Researcher - Researches finance and fintech news and trends
# 2.   Aggregator Agent - Combines all research findings into a single summary

# %%
# Create tech_researcher agent: Focuses on AI and ML trends.

tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Creat health_researcher agent: Focuses on medical breakthroughs.

health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Create finance_researcher: Focuses on fintech trends.

finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.

aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}

    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}

    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# Create parellel and sequential agents.

# The ParallelAgent runs all its sub-agents simultaneously.

parallel_agent = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher]
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.

root_agent = SequentialAgent(
    name="ResearchPipeline",
    sub_agents=[parallel_agent, aggregator_agent]
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
# Create run time environment and run the agent

runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **Key AI/ML Trends in 2025**
#
# Three prominent AI/ML trends shaping 2025 are:
#
# 1.  **Generative AI Expansion:** Generative AI is moving beyond text to create complex multimedia content like graphics, video, and music. Companies like **Google** (with Imagen and Muse) and **OpenAI** are at the forefront of this advancement. This trend enhances creative expression and offers practical applications across industries.
#
# 2.  **Shift to Smaller Language Models (SLMs):** While Large Language Models (LLMs) have dominated, there's a growing trend towards SLMs, offering more efficient and specialized capabilities. This transition aims for better performance and resource optimization.
#
# 3.  **AI in Edge Computing:** Processing data closer to the source (edge computing) is gaining traction, reducing latency and enabling real-time analytics. This is crucial for industries like healthcare (wearable devices) and manufacturing, with companies like **Google Cloud** offering edge computing solutions.
#
# **Main Companies Involved:**
#
# Key players driving these trends include **NVIDIA** (providing essential GPU hardware), **Microsoft** (investing heavily in AI infrastructure and partnerships with OpenAI), **Google** (developing advanced AI models and cloud platforms), **OpenAI** (leading LLM development), **Anthropic**, **Databricks**, and **Adobe** (integrating generative AI into creative tools).
#
# **Potential Impact:**
#
# These AI/ML trends are poised to significantly impact productivity, automation, and decision-making across sectors. They will drive innovation, create new business models, and redefine job roles, necessitating upskilling and adaptation within the workforce. Ethical considerations and regulatory frameworks will also become increasingly important as AI integration deepens.
# FinanceResearcher > Here's your daily executive briefing:
#
# **Technology:** Key trends include the integration of AI into enterprise software, the continued expansion of cloud-native architectures, and the growing importance of cybersecurity in a distributed workforce. Market implications involve increased operational efficiency, a demand for specialized IT talent, and a heightened focus on data privacy and compliance. The future outlook suggests AI will drive hyper-personalization and automation, while cloud adoption will deepen, making robust security paramount.
#
# **Health:** Major trends encompass the rise of personalized medicine, the increasing adoption of telehealth and remote patient monitoring, and the growing focus on preventative care and wellness. Market implications include a shift towards value-based care, enhanced patient access and engagement, and a greater emphasis on data analytics for better health outcomes. The future outlook points to a more patient-centric healthcare system, driven by technological innovation and a proactive approach to health.
#
# **Finance:** Three key trends are the proliferation of embedded finance, the ongoing evolution of decentralized finance (DeFi), and the increasing use of AI and machine learning for fraud detection and risk management. Market implications involve new revenue streams for non-financial companies, greater accessibility and transparency in financial services, and improved security and efficiency in financial operations. The future outlook suggests a more integrated and automated financial ecosystem, with enhanced personalization and risk mitigation capabilities.
# HealthResearcher > ## Daily Executive Briefing: Tech, Health, and Finance
#
# **Health:** Recent medical breakthroughs include pig-to-human kidney transplants, offering hope for those on transplant waitlists. A new blood test for Alzheimer's shows promise for earlier diagnosis. Gene therapy continues to advance, successfully treating genetic diseases and blindness, with ongoing research for cancer applications. Within the next 1-3 years, we can expect wider accessibility and clinical trials for these therapies.
#
# **Tech:** Agentic AI, capable of autonomous multi-step workflows, is a key emerging trend. Advancements in quantum computing are moving towards practical applications, though widespread impact may be 5-10 years away. Neural interfaces (Brain-Computer Interfaces) are progressing from labs to real-world uses, driven by AI, with potential applications in medicine and beyond within 3-5 years.
#
# **Finance:** Blockchain and DLT are modernizing payment infrastructure, enabling near-real-time settlement between banks. AI and machine learning are revolutionizing risk assessment and customer experience. The rise of digital assets and cryptocurrencies is creating new banking offerings and tokenization services. These financial innovations are largely available now or expected to mature within 1-3 years.
# AggregatorAgent > ## Executive Briefing: Interconnected Strides in Tech, Health, and Finance
#
# AI is the unifying force across all three sectors, driving innovation and operational efficiency. In technology, generative AI is expanding beyond text to multimedia, while a shift towards smaller, more efficient language models (SLMs) and AI in edge computing are key trends for 2025. This AI integration is mirrored in finance, where machine learning enhances fraud detection and risk management, alongside advancements in blockchain for modernized payment infrastructure and digital asset offerings.
#
# The health sector is experiencing remarkable breakthroughs, including promising early Alzheimer's detection via blood tests and advancements in gene therapy for genetic diseases and blindness. These health innovations are increasingly powered by AI, with the rise of telehealth and remote monitoring, alongside potential future applications of neural interfaces.
#
# Across the board, these developments point towards a future of increased automation, hyper-personalization, and enhanced efficiency. Key players like Google, Microsoft, and NVIDIA are instrumental in pushing these boundaries. However, this progress also necessitates a focus on workforce adaptation, ethical considerations, and robust cybersecurity measures.

# %% [markdown]
# ## Loop Workflows - The Refinement Cyc